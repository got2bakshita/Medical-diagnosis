# %% [markdown]
# # **Project Name**    - Healthcare Dataset

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Team
# ##### **Team Member 1 - Arnav Negi**
# ##### **Team Member 2 - Arayana Singh**
# ##### **Team Member 3 - Ayush Singh**
# ##### **Team Member 4 - Akshita Sharda**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# (https://github.com/got2bakshita/Medical-diagnosis)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Medical institutions generate vast amounts of data through patient records, including demographic information, symptoms, and diagnostic outcomes. Leveraging this data for predictive analysis can assist healthcare professionals in making more accurate diagnoses and improving patient care.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

# %%
pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

# %%
pip install nbformat>=4.2.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
ds = pd.read_csv('healthcare_dataset.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
ds.head(10)
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
# 5       Patrick Parker   41    Male        AB+         Arthritis
# 6       Charles Horton   82    Male        AB+      Hypertension
# 7         Patty Norman   55  Female         O-         Arthritis
# 8           Ryan Hayes   33    Male         A+          Diabetes
# 9         Sharon Perez   39  Female         O-            Asthma
#
#   Date of Admission           Doctor                   Hospital  \
# 0        2022-11-17   Patrick Parker           Wallace-Hamilton
# 1        2023-06-01    Diane Jackson  Burke, Griffin and Cooper
# ...

# %%
ds.tail(10)
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 9990         Tracy Johnson   35    Male         A+         Arthritis
# 9991           John Holder   56  Female         A+            Asthma
# 9992     Gabriel Rodriguez   37    Male         O+      Hypertension
# 9993         Michael Munoz   39    Male         O-      Hypertension
# 9994          Jorge Obrien   69    Male         A+          Diabetes
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                      Hospital  \
# 9990        2020-10-30          Paul Bell  Freeman, Nguyen and Ferguson
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
row_col= ds.shape

# %%
row_count=row_col[0]
col_count=row_col[1]

# %%
row_count
# Out:
# 10000

# %%
col_count
# Out:
# 15

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
ds.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
ds.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
ds.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
ds.isnull()
# Out:
#        Name    Age  Gender  Blood Type  Medical Condition  Date of Admission  \
# 0     False  False   False       False              False              False
# 1     False  False   False       False              False              False
# 2     False  False   False       False              False              False
# 3     False  False   False       False              False              False
# 4     False  False   False       False              False              False
# ...     ...    ...     ...         ...                ...                ...
# 9995  False  False   False       False              False              False
# 9996  False  False   False       False              False              False
# 9997  False  False   False       False              False              False
# 9998  False  False   False       False              False              False
# 9999  False  False   False       False              False              False
#
# ...

# %%
ds.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(ds.isnull(),cmap='viridis')
plt.title("Null Values Graph")
plt.show()

# %%
type(ds)
# Out:
# pandas.core.frame.DataFrame

# %%
nc = ds.isnull().sum(axis=0) 
plt.hist(nc, bins=range(max(nc)+2), align='left', rwidth=0.8)
plt.xlabel('NUMBER OF NULL VALUES')
plt.ylabel('COUNT')
plt.title('HISTOGRAM')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Visualizing the distribution of null values across different columns in your dataset. The histogram will show you how many columns have a certain number of null values, helping you understand the extent of missing data in your dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
columns= ds.columns
print("Dataset Columns: ")
print(columns)
# Out:
# Dataset Columns:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
# Dataset Describe
ds.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %%
ds.describe
# Out:
# <bound method NDFrame.describe of                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# %%
for column in ds.columns:
    unique_values=ds[column].unique()
    print(f"Unique values for {column}: {unique_values}\n")
# Out:
# Unique values for Name: ['Tiffany Ramirez' 'Ruben Burns' 'Chad Byrd' ... 'Christopher Martinez'
#  'Amanda Duke' 'Eric King']
#
# Unique values for Age: [81 35 61 49 51 41 82 55 33 39 45 23 85 72 65 32 64 66 80 79 54 26 70 74
#  56 37 78 83 30 19 46 48 34 84 47 60 57 21 27 68 31 42 71 38 28 43 69 73
#  67 44 20 59 76 40 36 29 53 77 24 75 25 62 52 50 22 63 58 18]
#
# Unique values for Gender: ['Female' 'Male']
#
# Unique values for Blood Type: ['O-' 'O+' 'B-' 'AB+' 'A+' 'AB-' 'A-' 'B+']
#
# Unique values for Medical Condition: ['Diabetes' 'Asthma' 'Obesity' 'Arthritis' 'Hypertension' 'Cancer']
#
# Unique values for Date of Admission: ['2022-11-17' '2023-06-01' '2019-01-09' ... '2020-07-03' '2022-02-19'
#  '2022-07-29']
#
# Unique values for Doctor: ['Patrick Parker' 'Diane Jackson' 'Paul Baker' ... 'Robert Nicholson'
#  'Jamie Lewis' 'Tasha Avila']
#
# Unique values for Hospital: ['Wallace-Hamilton' 'Burke, Griffin and Cooper' 'Walton LLC' ...
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
#Analysis
for col in ds.select_dtypes(include='object'):
  if col !='Test Results':
    plt.figure(figsize=(10,5))
    plt.title(col)
    sns.countplot(x=col,data=ds,hue='Test Results',palette=['red','green','blue'])
    plt.show()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The code is aimed at understanding the distribution of different categories within each categorical column, while also considering the 'Test Results' for comparison. By visualizing this information, you can gain insights into how different categories correlate with the test results and potentially identify patterns or relationships in the data.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#Patients Age distribution
ds['Age'].hist(bins=20)
plt.title('Histogram of Patients Ages')
plt.xlabel('Ages in Years')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram provides a concise yet informative visualization of the distribution of patient ages, making it a suitable choice for understanding this aspect of the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  The histogram of patient ages provides valuable insights into the demographic characteristics of the patient population in the dataset, helping researchers or analysts better understand the data and potentially uncover relationships between age and other variables.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  While insights gained from the age distribution of patients can inform various strategic decisions and initiatives within a healthcare facility, such as targeted marketing, resource allocation, and preventive care programs, they can also highlight potential challenges, such as strain on resources and lack of diversity in the patient base, which may require careful management to mitigate negative impacts.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
fig = px.pie(ds, names='Medical Condition', title='Pie Chart for Medical Conditions')
fig.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a pie chart because it's commonly used for visualizing proportions or percentages of a whole. In this case, you're visualizing medical conditions, which likely have distinct categories. A pie chart allows you to easily see the distribution of these categories in relation to the whole dataset. It's particularly effective when you have a small number of categories and want to compare their relative sizes at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pie chart generated by the provided code, you can gain several insights depending on the data:
#
# 1. **Distribution of Medical Conditions**: The chart provides a visual representation of the distribution of various medical conditions present in the dataset. You can see which conditions are more prevalent or occur more frequently compared to others.
#
# 2. **Relative Proportions**: The size of each slice in the pie chart corresponds to the proportion of occurrences of each medical condition relative to the total number of occurrences in the dataset. This allows for a quick comparison of the prevalence of different conditions.
#
# 3. **Identifying Dominant Conditions**: It's easy to identify any dominant medical conditions by looking at the largest slices in the pie chart. These conditions are likely to be the most common or most significant within the dataset.
#
# 4. **Comparative Analysis**: You can compare the sizes of different slices to understand the relative frequencies of various medical conditions. This can help in identifying patterns or trends within the dataset.
#
# Overall, the pie chart provides a concise visual summary of the distribution of medical conditions in the dataset, allowing for quick insights into the prevalence and relative importance of different conditions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the pie chart could potentially lead to positive business impacts and may also highlight areas of concern or negative growth. Here's how:
#
# Positive Impacts:
# 1. **Resource Allocation**: Understanding the distribution of medical conditions can help in allocating resources more effectively. For example, if certain conditions are more prevalent, a business can focus its resources on developing products or services targeted towards addressing those conditions, potentially leading to increased customer satisfaction and revenue.
#
# 2. **Targeted Marketing**: Insights from the pie chart can inform targeted marketing efforts. Businesses can tailor their marketing strategies to appeal to customers with specific medical conditions, increasing the effectiveness of their campaigns and potentially attracting more customers.
#
# 3. **Product Development**: Knowledge of prevalent medical conditions can guide product development initiatives. Businesses can prioritize the development of products that address the most common or significant conditions, leading to the creation of more relevant and marketable solutions.
#
# Negative Growth:
# 1. **Overemphasis on Dominant Conditions**: While focusing on addressing prevalent conditions can be beneficial, it's essential to avoid overemphasizing them at the expense of less common conditions. Neglecting less common conditions that still affect a significant portion of the customer base can lead to dissatisfaction among those customers and may result in negative growth as competitors capitalize on underserved market segments.
#
# 2. **Failure to Address Emerging Trends**: If the pie chart only reflects current data without accounting for emerging trends or changing demographics, businesses may miss opportunities for growth. Ignoring emerging conditions or shifting customer preferences can lead to stagnation or decline in market share.
#
# In summary, while the insights gained from the pie chart can potentially lead to positive business impacts such as improved resource allocation, targeted marketing, and product development, there's a risk of negative growth if businesses solely focus on dominant conditions or fail to adapt to emerging trends. It's crucial for businesses to maintain a balanced approach and continually reassess their strategies based on evolving market dynamics.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#line chart 
date=ds['Date of Admission'].to_numpy()
date
# Out:
# array(['2022-11-17', '2023-06-01', '2019-01-09', ..., '2022-07-01',
#        '2020-02-06', '2023-03-22'], dtype=object)

# %%
from collections import Counter
from datetime import datetime

def count_dates_by_month_year(date_array):
    month_year_count = Counter()
    for date_str in date_array:
        date = datetime.strptime(date_str, "%Y-%m-%d")  
        month_year = date.strftime("%Y-%m")
        month_year_count[month_year] += 1
    return month_year_count\

result=count_dates_by_month_year(date)

months_years, counts = zip(*sorted(result.items()))

plt.figure(figsize=(10, 6))
plt.plot(months_years, counts, marker='o', linestyle='-', color='skyblue')
plt.title('Date Counts by Month and Year')
plt.xlabel('Month and Year')
plt.ylabel('Number of Admissions')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line plot is a suitable choice for visualizing the trend of admissions over time, allowing viewers to easily interpret and analyze the data for insights or patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The line plot provides a visual representation of the temporal distribution of admissions, allowing stakeholders to identify trends, patterns, and anomalies in the data for informed decision-making and strategic planning.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# While insights gained from analyzing admissions data over time can help healthcare businesses in resource planning, operational efficiency, and financial forecasting, they can also highlight challenges related to seasonal variability and capacity constraints that require proactive management to mitigate negative impacts and ensure sustainable growth.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
date=ds['Discharge Date'].to_numpy()
date
# Out:
# array(['2022-12-01', '2023-06-15', '2019-02-08', ..., '2022-07-15',
#        '2020-02-26', '2023-04-15'], dtype=object)

# %%
from collections import Counter
from datetime import datetime

def count_dates_by_month_year(date_array):
    month_year_count = Counter()
    for date_str in date_array:
        date = datetime.strptime(date_str, "%Y-%m-%d")  
        month_year = date.strftime("%Y-%m")
        month_year_count[month_year] += 1
    return month_year_count\

result=count_dates_by_month_year(date)

months_years, counts = zip(*sorted(result.items()))

plt.figure(figsize=(10, 6))
plt.plot(months_years, counts, marker='o', linestyle='-', color='skyblue')
plt.title('Date Counts by Month and Year')
plt.xlabel('Month and Year')
plt.ylabel('Number of Discharge')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart, a line plot, is suitable for visualizing the trend in the number of discharges over time, specifically by month and year. Here's why this chart is appropriate

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides valuable insights into the temporal distribution of discharges, allowing healthcare providers to optimize operations, anticipate demand, and respond effectively to fluctuations in patient flow.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# While insights gained from analyzing discharge data over time can help healthcare businesses in optimizing bed management, improving patient flow, and allocating resources effectively, they can also pose challenges related to capacity management and financial sustainability if not managed proactively.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %%
insurance_provider_distribution = ds['Insurance Provider'].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(insurance_provider_distribution, labels=insurance_provider_distribution.index, autopct='%1.1f%%', colors=['gold', 'lightcoral', 'lightblue', 'grey', 'blue'])
plt.title('Insurance Provider Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart is suitable for visualizing the distribution of categorical data, such as the distribution of insurance providers in this case.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart provides a clear visual representation of the distribution of insurance providers among the patient population, offering insights that can inform strategic decisions related to partnerships, marketing, and service delivery within the healthcare facility.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# While insights gained from analyzing insurance provider distribution can inform targeted marketing strategies, revenue management practices, and patient engagement initiatives, they can also highlight risks associated with dependency on specific providers and limitations in market reach. Proactive diversification of revenue sources and efforts to attract a broader patient demographic can mitigate negative impacts and foster sustainable growth for the healthcare business.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(15, 8))

# Box plot for Hospital
plt.subplot(1, 3, 1)
sns.boxplot(x='Medication', y='Medical Condition', data=ds)
plt.title('Medication Vs Medical Condition')

# Box plot for Insurance Provider
plt.subplot(1, 3, 2)
sns.boxplot(x='Insurance Provider', y='Medical Condition', data=ds)
plt.title('Insurance Provider Vs Medical Condition')



# Adjust layout for better readability
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This specific chart format is chosen for its ability to effectively compare distributions across categories and identify potential relationships between variables within the context of medical conditions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# These box plots provide visual insights into the relationships between medication, insurance provider, and medical conditions among patients in your dataset. They can help identify potential patterns, associations, or disparities that may warrant further investigation or intervention within the healthcare setting.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  While insights gained from analyzing treatment patterns, insurance provider relationships, and medical condition prevalence can inform personalized care, resource allocation, and strategic partnerships within a healthcare business, they can also highlight healthcare disparities and financial dependencies that require proactive management to mitigate negative impacts and foster equitable, sustainable growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
df1= ds.groupby(['Admission Type','Medical Condition'])['Age'].mean().unstack()
df1.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Admission Type'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It allows for easy comparison of both the overall age distribution across different medical conditions and admission types as well as the contribution of each medical condition to the total age within each admission type. The stacked bars help to visualize the composition of age within each category, making it easier to identify patterns and variations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart helps to visualize the relationship between admission type, medical condition, and patient age, allowing for better understanding and analysis of these factors in healthcare settings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There could potentially be negative growth if the insights reveal disparities or inadequacies in healthcare access or quality for certain age groups. For example, if the analysis shows that older adults with certain medical conditions have longer wait times or less access to specialized care compared to younger patients, it could indicate areas where improvements are needed. Failure to address these disparities could lead to negative consequences such as reduced patient satisfaction, lower treatment outcomes, and reputational damage for healthcare facilities. Therefore, it's essential for healthcare organizations to use these insights responsibly and take action to address any identified issues.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
heatmap_data = ds.pivot_table(index='Blood Type', aggfunc='size').reset_index(name='Count')

# Create the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data.pivot(index='Blood Type', columns='Count', values='Count'),
            annot=True, cmap="YlGnBu", fmt='g', cbar=False)
plt.title('Blood Group Heatmap')
plt.xlabel('Count')
plt.ylabel('Blood Type')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The heatmap chart is chosen here because it effectively visualizes the frequency distribution of blood types in a dataset. Heatmaps are particularly useful for displaying categorical data where the values can be easily represented by colors

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap provides a visually appealing and informative way to analyze the distribution of blood types within the dataset, which can be valuable for healthcare professionals and researchers working in fields related to blood transfusion, genetics, and epidemiology.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# While the insights from the heatmap may not directly lead to negative growth, there are potential risks if healthcare facilities fail to adequately manage their blood product inventory or address the needs of patients with less common blood types. Inadequate inventory management could lead to shortages or wastage of blood products, impacting patient care and potentially damaging the facility's reputation. Additionally, if patients with less common blood types experience delays or difficulties in accessing appropriate blood products, it could lead to negative patient outcomes and decreased satisfaction. Therefore, it's essential for healthcare facilities to use insights from the heatmap to inform their strategic planning and operational decisions to mitigate these risks and ensure optimal patient care.

# %% [markdown]
# #### Chart - 9

# %%
ds['Discharge Date'] = pd.to_datetime(ds['Discharge Date'])
ds.sort_values('Discharge Date', inplace=True)
medication_distribution = ds.groupby('Discharge Date')['Medication'].count()
plt.figure(figsize=(12, 6))
plt.plot(medication_distribution.index, medication_distribution.values, marker='o', color='green')
plt.title('Medication Distribution Over Time')
plt.xlabel('Discharge Date')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a line plot to visualize the medication distribution over time because it effectively illustrates the trend and changes in medication counts over a period

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides valuable insights into the patterns and trends of medication distribution within the healthcare facility, which can inform strategic planning, resource allocation, and quality improvement initiatives.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There are potential risks if the insights reveal issues such as medication errors, inadequate medication supply, or deviations from clinical guidelines. These issues can lead to negative growth by impacting patient safety, satisfaction, and outcomes, as well as increasing liability and regulatory scrutiny. Therefore, it's essential for healthcare facilities to use insights from medication distribution analysis to identify and address any potential areas for improvement in their medication management processes, ultimately enhancing patient care and business performance.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %%
import plotly.graph_objects as go
fig = go.Figure(data=go.Violin(y=ds['Doctor'], box_visible=True, line_color='black',
                               meanline_visible=True, fillcolor='lightseagreen', opacity=0.6,
                               x0='Doctor'))

fig.update_layout(yaxis_zeroline=False)
fig.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The violin plot is a versatile and informative visualization tool that effectively communicates the distribution of doctors within the dataset, making it a suitable choice for this analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  The violin plot helps visualize the distribution of patients among different doctors and provides insights into the variability and central tendency of patient counts within the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There are potential risks if the insights reveal disparities in workload distribution among doctors, such as certain doctors being consistently overloaded while others have lighter workloads. This could lead to negative growth by impacting patient outcomes, staff morale, and overall efficiency. Additionally, if workload imbalances are not addressed, they may contribute to burnout among healthcare providers, leading to decreased productivity and increased turnover, which can further strain resources and negatively impact business performance. Therefore, it's essential for healthcare facilities to use insights from workload distribution analysis to identify and address any potential areas for improvement in their workforce management practices.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(10, 6))
scatter = plt.scatter(ds['Age'], ds['Billing Amount'], s=ds['Billing Amount']/500, c=ds['Insurance Provider'].astype('category').cat.codes, cmap='viridis', alpha=0.7)

# Add labels and legend
plt.title('Bubble Chart of Patient Data')
plt.xlabel('Age')
plt.ylabel('Billing Amount')
legend = plt.legend(*scatter.legend_elements(), title='Insurance Provider')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose to create a bubble chart for the given data because it allows us to visualize the relationship between three variables: age, billing amount, and insurance provider

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart provides a comprehensive visualization of the relationship between age, billing amount, and insurance provider, enabling insights into potential trends, patterns, and disparities in healthcare billing data

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  The key is to carefully analyze the insights gained from the data and use them to make informed decisions that will drive positive business outcomes while addressing any potential negative implications.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# Create a pivot table to count occurrences of each medication for each medical condition
heatmap_data = ds.groupby(['Medical Condition', 'Medication']).size().unstack(fill_value=0)

# Plot the heatmap
plt.figure(figsize=(15, 8))
sns.heatmap(heatmap_data, annot=True, cmap="YlOrRd", fmt='g', cbar_kws={'label': 'Number of Patients'})
plt.title('Medication vs. Medical Condition')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose to create a heatmap because it is an effective way to visualize the relationship between two categorical variables, in this case, medications and medical conditions. The heatmap provides a clear and intuitive representation of the frequency of each medication prescribed for each medical condition

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap provides a comprehensive overview of medication usage patterns across different medical conditions, facilitating better understanding and decision-making in healthcare management and treatment planning.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  The insights gained from the heatmap visualization can provide valuable information for improving patient care and organizational efficiency, it is essential to carefully evaluate the implications of medication usage patterns to mitigate potential risks and ensure positive outcomes for both patients and the business.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
medication_counts = ds['Medication'].value_counts()

# Plot the horizontal bar graph
plt.figure(figsize=(10, 6))
medication_counts.plot(kind='barh', color='purple')
plt.xlabel('Number of Patients')
plt.title('Medication Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The horizontal bar graph is a suitable choice for visualizing the distribution of medication across different categories because it allows for easy comparison of the frequency of each medication.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides a visual representation of the medication distribution among patients, which can help healthcare professionals better understand prescribing patterns and potentially identify areas for improvement or further investigation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from medication distribution data have the potential to drive positive business outcomes by informing decision-making and optimizing healthcare delivery.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
numerical_columns = ds.select_dtypes(include=['int64', 'float64'])


color_palette = 'Paired'

# Create pair plot
sns.pairplot(numerical_columns)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
